# %%
#Imnporting libraries
import pandas as pd
import numpy as np
import os
from gurobipy import * 

#Listing the existing files in the dir
for root, dirs, files in os.walk("."):  
    for filename in files:
        print(filename)
# Out:
# code.ipynb
# COMMIT_EDITMSG
# config
# description
# HEAD
# index
# applypatch-msg.sample
# commit-msg.sample
# fsmonitor-watchman.sample
# post-update.sample
# pre-applypatch.sample
# pre-commit.sample
# pre-push.sample
# pre-rebase.sample
# pre-receive.sample
# prepare-commit-msg.sample
# update.sample
# exclude
# HEAD
# master
# master
# cda8e721177be429e875da5b6c54d1f634833e
# 9df40e4ae146d34b7773563240d9efdda9e13f
# c7dc1f57ab6a5182737cf1ea92f30e38ea0791
# 55c9c636a1fa6beff97d46afdd2bfaf4b9f554
# d96abeba6d5e13c8374fe78607e06bc52f6afb
# ca30d1eaec6b80c5ee8d3df83b6fb00c81ab27
# 8995527d7106738065c43853e7171001d9de97
# master
# master
# code-checkpoint.ipynb
# data-2018-09-24.csv

# %%
#Loading df
df = pd.read_csv('./files/data-2018-09-24.csv')
df = df.drop(df.loc[:,['name', 'pft']].head(0).columns, axis=1)
inpt_df = df.iloc[:, 1:6]
inpt_arr = np.array(inpt_df).reshape(-1, 1)
outpt_df = df.iloc[:, 6:]
outpt_arr = np.array(outpt+df).reshape(-1, 1)
comp = np.array(df.iloc[:, 0])

# %%
# a temporal list of input categories 
inpt_categories = ['x1', 'x2', 'x3', 'x4', 'x5'] 
inpt_tuple_list = [(inp, c) for c in comp for inp in inpt_categories] 
inpt = {}
for i in range(len(inpt_tuple_list)): 
      inpt[inpt_tuple_list[i]] = inpt_arr[i][0] 
outpt_categories = ['y1', 'y2', 'y3'] 
outpt = {}
for i in range(len(inpt_tuple_list)): 
      outpt[inpt_tuple_list[i]] = outpt_arr[i][0] 

def solve(categories, minNutrition, maxNutrition, foods, cost,
          nutritionValues):
    # Model
    m = Model("benchmarking")
    inefficiency = m.addVar(lb=0.0, vtype=GRB.CONTINUOUS, obj=1.0, name="Inefficiency") 
    weight = m.addVars(garages, lb=0.0, vtype=GRB.CONTINUOUS, name="Weight") 

    # Create decision variables for the foods to buy
    weights = m.addVars(comp, name="weights")

    # The objective is to minimize the costs
    m.setObjective(buy.prod(cost), GRB.MINIMIZE)

    # Nutrition constraints
    m.addConstrs(
        (quicksum(nutritionValues[f,c] * buy[f] for f in foods)
        	== [minNutrition[c], maxNutrition[c]]
         for c in categories), "_")

# %%
garages = ['Winchester', 'Andover', 'Basingstoke', 'Poole', 'Woking', 'Newbury', 'Portsmouth', 
            'Alresford', 'Salisbury', 'Guildford', 'Alton', 'Weybridge', 'Dorchester', 'Bridport', 
              'Weymouth', 'Portland', 'Chichester', 'Petersfield', 'Petworth', 'Midhurst','Reading', 
              'Southampton', 'Bournemouth', 'Henley', 'Maidenhead', 'Fareham', 'Romsey', 'Ringwood'] 
    
   # staff 
staff = np.array([7., 6., 2., 14., 10., 24., 6., 8., 5., 8., 7., 5., 6., 11., 
                  4., 3., 5., 21., 6., 3., 30., 25., 19., 7., 12., 4., 2., 2.])
showroom = np.array([8., 6., 3., 9., 9., 15., 7., 7.5, 5., 10., 8., 6.5, 7.5, 8., 
                     5., 3.5, 5.5, 12., 5.5, 3.6, 29., 16., 10., 6., 8., 6., 2.5, 3.5])
pop1 = np.array([10., 20., 40., 20., 10., 15., 50., 5., 10., 30., 7., 9., 10., 8., 
                 10., 3., 8., 6., 2., 3., 120., 110., 90., 5., 7., 1., 1., 2.])
pop2 = np.array([12., 30., 40., 25., 10., 13. ,40., 8., 10., 35., 8., 12., 10., 10., 
                   10., 20., 10., 6., 2., 3., 80., 80., 22., 7., 10., 1., 1., 2.]) 
alpha_enq = np.array([8.5, 9., 2., 10., 11., 25., 8.5, 9., 5., 9.5, 3., 8., 7.5, 10., 
                         7.5, 2., 7., 15., 8., 2.5, 35., 27., 25., 8.5, 12., 7.5, 2.5, 1.9]) 
beta_enq = np.array([4., 4.5, 1.5, 6., 5., 1.9, 3., 4., 2.5, 4.5, 2., 4.5, 4., 6., 
                       3.5, 1.5, 3.5, 8., 5., 1.5, 20., 12., 13., 4.5, 7., 3.5, 1., 1.2]) 
alpha_sales = np.array([2., 2.3, 0.8, 2.6, 2.4, 8., 2.5, 2.1, 2., 2.05, 1.9, 1.8, 1.5, 2.2, 
                           1.8, 0.9, 1.2, 6., 1.5, 0.8, 7., 6.5, 5.5, 1.2, 4.5, 1.1, 0.4, 0.3]) 
beta_sales = np.array([0.6, 0.7, 0.25, 0.86, 1., 2.6, 0.9, 0.85, 0.65, 0.75, 0.7, 0.63, 0.45, 0.65, 
                          0.62, 0.35, 0.45, 0.25, 0.55, 0.2, 2.5, 3.5, 3.1, 0.48, 2., 0.48, 0.1, 0.09]) 
profit = np.array([1.5, 1.6, 0.5, 1.9, 2., 4.5, 1.6, 2., 0.9, 1.7, 0.5, 1.4, 1.45, 2.2, 
                      1.6, 0.5, 1.3, 2.9, 1.55, 0.45, 8., 5.4, 4.5, 2., 2.3, 1.7, 0.55, 0.4]) 
input_matrix = np.array([]) 
input_matrix = np.vstack((staff, showroom, pop1, pop2, alpha_enq, beta_enq)) 
# input_matrix array is [6, 28] 
input_matrix = np.transpose(input_matrix) 
 # finally flatten input_matrix 
input_matrix  = np.reshape(input_matrix, [input_matrix.shape[0]*input_matrix.shape[1], 1]) 
output_matrix = np.array([]) 
output_matrix = np.vstack((alpha_sales, beta_sales, profit)) 
output_matrix = np.transpose(output_matrix) 
output_matrix = np.reshape(output_matrix, [output_matrix.shape[0]*output_matrix.shape[1], 1]) 
input_categories = ['Staff', 'Showroom', 'Population-1', 'Population-2', 'Alpha-Enquiries', 'Beta-Enquiries'] 
icg_tuple_list = [(ic, g) for g in garages for ic in input_categories] 
input = {} 
for i in range(len(icg_tuple_list)): 
       input[icg_tuple_list[i]] = input_matrix[i][0] 
   # now input is a dictionary [(input_category, garage): value] 
input_matrix
# Out:
# array([[  7. ],
#        [  8. ],
#        [ 10. ],
#        [ 12. ],
#        [  8.5],
#        [  4. ],
#        [  6. ],
#        [  6. ],
#        [ 20. ],
#        [ 30. ],
#        [  9. ],
#        [  4.5],
#        [  2. ],
#        [  3. ],
#        [ 40. ],
#        [ 40. ],
#        [  2. ],
#        [  1.5],
#        [ 14. ],
#        [  9. ],
#        [ 20. ],
#        [ 25. ],
#        [ 10. ],
#        [  6. ],
#        [ 10. ],
#        [  9. ],
#        [ 10. ],
#        [ 10. ],
#        [ 11. ],
#        [  5. ],
#        [ 24. ],
#        [ 15. ],
#        [ 15. ],
#        [ 13. ],
#        [ 25. ],
#        [  1.9],
#        [  6. ],
#        [  7. ],
#        [ 50. ],
#        [ 40. ],
#        [  8.5],
#        [  3. ],
#        [  8. ],
#        [  7.5],
#        [  5. ],
#        [  8. ],
#        [  9. ],
#        [  4. ],
#        [  5. ],
#        [  5. ],
#        [ 10. ],
#        [ 10. ],
#        [  5. ],
#        [  2.5],
#        [  8. ],
# ...

# %%
input
# Out:
# {('Alpha-Enquiries', 'Alresford'): 9.0,
#  ('Alpha-Enquiries', 'Alton'): 3.0,
#  ('Alpha-Enquiries', 'Andover'): 9.0,
#  ('Alpha-Enquiries', 'Basingstoke'): 2.0,
#  ('Alpha-Enquiries', 'Bournemouth'): 25.0,
#  ('Alpha-Enquiries', 'Bridport'): 10.0,
#  ('Alpha-Enquiries', 'Chichester'): 7.0,
#  ('Alpha-Enquiries', 'Dorchester'): 7.5,
#  ('Alpha-Enquiries', 'Fareham'): 7.5,
#  ('Alpha-Enquiries', 'Guildford'): 9.5,
#  ('Alpha-Enquiries', 'Henley'): 8.5,
#  ('Alpha-Enquiries', 'Maidenhead'): 12.0,
#  ('Alpha-Enquiries', 'Midhurst'): 2.5,
#  ('Alpha-Enquiries', 'Newbury'): 25.0,
#  ('Alpha-Enquiries', 'Petersfield'): 15.0,
#  ('Alpha-Enquiries', 'Petworth'): 8.0,
#  ('Alpha-Enquiries', 'Poole'): 10.0,
#  ('Alpha-Enquiries', 'Portland'): 2.0,
#  ('Alpha-Enquiries', 'Portsmouth'): 8.5,
#  ('Alpha-Enquiries', 'Reading'): 35.0,
#  ('Alpha-Enquiries', 'Ringwood'): 1.9,
#  ('Alpha-Enquiries', 'Romsey'): 2.5,
#  ('Alpha-Enquiries', 'Salisbury'): 5.0,
# ...
